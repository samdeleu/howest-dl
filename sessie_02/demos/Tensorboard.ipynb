# %%
# %matplotlib inline
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import OneHotEncoder
from sklearn import preprocessing

import matplotlib.image as mpimg


from scipy import ndimage
#import Tensorflow namespaces

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation

from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing import image

from tensorflow.keras.callbacks import TensorBoard


import pickle
import time

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# Load training set and test set

training_data = unpickle('./cifar-10/data_batch_1')
test_data = unpickle('./cifar-10/test_batch')

# Create training set and test set

X_train = training_data.get(b'data')
train_labels = training_data.get(b'labels')

X_test = test_data.get(b'data')
test_labels = test_data.get(b'labels')

# Reshape into Tensorflow format (number of images, width, height, color channels)

X_train = X_train.reshape((len(X_train),3,32,32)).transpose(0,2,3,1)
X_test  = X_test.reshape((len(X_test),3,32,32)).transpose(0,2,3,1)

# Normalisatie
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# one-hot encoding of the labels

y_train = to_categorical(train_labels)
y_test = test_labels

# %%
NAME = 'CIFAR-10_CNN_Dropout_10_Percent'.format(int(time.time()))
tensorboard = TensorBoard(log_dir='logs/{}'.format(NAME))

# %%
# Neural network parameters
#-----------------------------------------------
#-----------------------------------------------
batch_size = 64 # 
epochs = 30 # 
dropoutRate = 0.1
#-----------------------------------------------
#-----------------------------------------------
num_classes = 10
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols,3)

# Model
model = Sequential()
#-----------------------------------------------
#-----------------------------------------------
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=input_shape)) 
#-----------------------------------------------
#-----------------------------------------------
model.add(MaxPooling2D(pool_size=(2, 2)))
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(dropoutRate)) # Value between 0 and 1 
#-----------------------------------------------
model.add(BatchNormalization())
#-----------------------------------------------
model.add(Conv2D(32, (3, 3), activation='relu')) 
#-----------------------------------------------
#-----------------------------------------------
model.add(MaxPooling2D(pool_size=(2, 2)))
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(dropoutRate)) # Value between 0 and 1 
#-----------------------------------------------
model.add(BatchNormalization())
#-----------------------------------------------
#-----------------------------------------------
model.add(Flatten()) 
model.add(Dense(50, activation='relu')) 
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(dropoutRate)) # Value between 0 and 1 
#-----------------------------------------------
#-----------------------------------------------
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Trainen van het CNN
history = model.fit(X_train, y_train,batch_size=batch_size, epochs=epochs, validation_split=0.2, verbose=1, callbacks = [tensorboard])
# Out:
# Epoch 1/30
# 125/125 [==============================] - 2s 15ms/step - loss: 2.0297 - accuracy: 0.3022 - val_loss: 2.5176 - val_accuracy: 0.1355
# Epoch 2/30
# 125/125 [==============================] - 2s 14ms/step - loss: 1.5823 - accuracy: 0.4372 - val_loss: 2.6466 - val_accuracy: 0.1675
# Epoch 3/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.4070 - accuracy: 0.4926 - val_loss: 2.1517 - val_accuracy: 0.2460
# Epoch 4/30
# 125/125 [==============================] - 2s 14ms/step - loss: 1.2640 - accuracy: 0.5531 - val_loss: 1.7946 - val_accuracy: 0.3685
# Epoch 5/30
# 125/125 [==============================] - 2s 15ms/step - loss: 1.1816 - accuracy: 0.5763 - val_loss: 1.4435 - val_accuracy: 0.5110
# Epoch 6/30
# 125/125 [==============================] - 2s 15ms/step - loss: 1.0680 - accuracy: 0.6160 - val_loss: 1.3810 - val_accuracy: 0.5100
# Epoch 7/30
# 125/125 [==============================] - 2s 15ms/step - loss: 1.0212 - accuracy: 0.6390 - val_loss: 1.2990 - val_accuracy: 0.5450
# Epoch 8/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.9496 - accuracy: 0.6641 - val_loss: 1.2495 - val_accuracy: 0.5630
# Epoch 9/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.8837 - accuracy: 0.6836 - val_loss: 1.2456 - val_accuracy: 0.5745
# Epoch 10/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.8315 - accuracy: 0.7051 - val_loss: 1.2249 - val_accuracy: 0.5790
# Epoch 11/30
# 125/125 [==============================] - 2s 16ms/step - loss: 0.7767 - accuracy: 0.7237 - val_loss: 1.5293 - val_accuracy: 0.5345
# Epoch 12/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.7256 - accuracy: 0.7402 - val_loss: 1.2175 - val_accuracy: 0.6080
# Epoch 13/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.6801 - accuracy: 0.7580 - val_loss: 1.2817 - val_accuracy: 0.5750
# Epoch 14/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.6422 - accuracy: 0.7670 - val_loss: 1.2315 - val_accuracy: 0.5965
# Epoch 15/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.6069 - accuracy: 0.7862 - val_loss: 1.2674 - val_accuracy: 0.5935
# Epoch 16/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.5916 - accuracy: 0.7861 - val_loss: 1.3003 - val_accuracy: 0.5835
# Epoch 17/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.5549 - accuracy: 0.7996 - val_loss: 1.4115 - val_accuracy: 0.5755
# Epoch 18/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.5221 - accuracy: 0.8112 - val_loss: 1.2761 - val_accuracy: 0.6025
# Epoch 19/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.4972 - accuracy: 0.8251 - val_loss: 1.3817 - val_accuracy: 0.5895
# Epoch 20/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.4823 - accuracy: 0.8304 - val_loss: 1.4942 - val_accuracy: 0.5560
# Epoch 21/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.4512 - accuracy: 0.8396 - val_loss: 1.5391 - val_accuracy: 0.5830
# Epoch 22/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.4489 - accuracy: 0.8371 - val_loss: 1.4829 - val_accuracy: 0.5780
# Epoch 23/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.4316 - accuracy: 0.8429 - val_loss: 1.4407 - val_accuracy: 0.5865
# Epoch 24/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.3964 - accuracy: 0.8581 - val_loss: 1.5516 - val_accuracy: 0.5695
# Epoch 25/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.3890 - accuracy: 0.8576 - val_loss: 1.5481 - val_accuracy: 0.5805
# Epoch 26/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.3847 - accuracy: 0.8649 - val_loss: 1.5385 - val_accuracy: 0.5835
# Epoch 27/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.3563 - accuracy: 0.8727 - val_loss: 1.4878 - val_accuracy: 0.6010
# Epoch 28/30
# 125/125 [==============================] - 2s 16ms/step - loss: 0.3567 - accuracy: 0.8698 - val_loss: 1.6117 - val_accuracy: 0.5745
# Epoch 29/30
# 125/125 [==============================] - 2s 15ms/step - loss: 0.3493 - accuracy: 0.8795 - val_loss: 1.6306 - val_accuracy: 0.5830
# Epoch 30/30
# 125/125 [==============================] - 2s 16ms/step - loss: 0.3321 - accuracy: 0.8810 - val_loss: 1.5496 - val_accuracy: 0.5925

# %%
# Second model


NAME = 'CIFAR-10_CNN_Dropout_30_Percent'.format(int(time.time()))
tensorboard = TensorBoard(log_dir='logs/{}'.format(NAME))

# %%
# Neural network parameters
#-----------------------------------------------
#-----------------------------------------------
batch_size = 64 # 
epochs = 30 # 
dropoutRate = 0.3
#-----------------------------------------------
#-----------------------------------------------
num_classes = 10
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols,3)

# Model
model = Sequential()
#-----------------------------------------------
#-----------------------------------------------
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=input_shape)) 
#-----------------------------------------------
#-----------------------------------------------
model.add(MaxPooling2D(pool_size=(2, 2)))
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(dropoutRate)) # Value between 0 and 1 
#-----------------------------------------------
model.add(BatchNormalization())
#-----------------------------------------------
model.add(Conv2D(32, (3, 3), activation='relu')) 
#-----------------------------------------------
#-----------------------------------------------
model.add(MaxPooling2D(pool_size=(2, 2)))
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(dropoutRate)) # Value between 0 and 1 
#-----------------------------------------------
model.add(BatchNormalization())
#-----------------------------------------------
#-----------------------------------------------
model.add(Flatten()) 
model.add(Dense(50, activation='relu')) 
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(dropoutRate)) # Value between 0 and 1 
#-----------------------------------------------
#-----------------------------------------------
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Trainen van het CNN
history = model.fit(X_train, y_train,batch_size=batch_size, epochs=epochs, validation_split=0.2, verbose=1, callbacks = [tensorboard])
# Out:
# Epoch 1/30
# 125/125 [==============================] - 2s 14ms/step - loss: 2.3743 - accuracy: 0.2249 - val_loss: 2.6884 - val_accuracy: 0.1145
# Epoch 2/30
# 125/125 [==============================] - 2s 14ms/step - loss: 1.8452 - accuracy: 0.3425 - val_loss: 3.4860 - val_accuracy: 0.1410
# Epoch 3/30
# 125/125 [==============================] - 2s 14ms/step - loss: 1.6657 - accuracy: 0.3954 - val_loss: 2.8577 - val_accuracy: 0.1355
# Epoch 4/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.5700 - accuracy: 0.4231 - val_loss: 2.5031 - val_accuracy: 0.1865
# Epoch 5/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.4980 - accuracy: 0.4581 - val_loss: 1.9291 - val_accuracy: 0.3345
# Epoch 6/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.4581 - accuracy: 0.4667 - val_loss: 1.8126 - val_accuracy: 0.3625
# Epoch 7/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.4033 - accuracy: 0.4934 - val_loss: 1.4000 - val_accuracy: 0.5110
# Epoch 8/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.3673 - accuracy: 0.5038 - val_loss: 1.6313 - val_accuracy: 0.4170
# Epoch 9/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.3252 - accuracy: 0.5228 - val_loss: 1.3639 - val_accuracy: 0.5200
# Epoch 10/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.2979 - accuracy: 0.5325 - val_loss: 1.4503 - val_accuracy: 0.4795
# Epoch 11/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.2578 - accuracy: 0.5520 - val_loss: 1.2655 - val_accuracy: 0.5400
# Epoch 12/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.2343 - accuracy: 0.5543 - val_loss: 1.2560 - val_accuracy: 0.5520
# Epoch 13/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.2233 - accuracy: 0.5626 - val_loss: 1.2916 - val_accuracy: 0.5350
# Epoch 14/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.1758 - accuracy: 0.5799 - val_loss: 1.3426 - val_accuracy: 0.5560
# Epoch 15/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.1706 - accuracy: 0.5770 - val_loss: 1.3716 - val_accuracy: 0.5215
# Epoch 16/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.1426 - accuracy: 0.5916 - val_loss: 1.5599 - val_accuracy: 0.4795
# Epoch 17/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.1194 - accuracy: 0.5949 - val_loss: 1.2593 - val_accuracy: 0.5630
# Epoch 18/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.0998 - accuracy: 0.6100 - val_loss: 1.1892 - val_accuracy: 0.5805
# Epoch 19/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.0921 - accuracy: 0.6104 - val_loss: 1.2650 - val_accuracy: 0.5710
# Epoch 20/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.0665 - accuracy: 0.6221 - val_loss: 1.2364 - val_accuracy: 0.5695
# Epoch 21/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.0509 - accuracy: 0.6231 - val_loss: 1.2935 - val_accuracy: 0.5545
# Epoch 22/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.0155 - accuracy: 0.6330 - val_loss: 1.2659 - val_accuracy: 0.5570
# Epoch 23/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.0037 - accuracy: 0.6349 - val_loss: 1.2772 - val_accuracy: 0.5545
# Epoch 24/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9902 - accuracy: 0.6501 - val_loss: 1.2147 - val_accuracy: 0.5785
# Epoch 25/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9848 - accuracy: 0.6389 - val_loss: 1.1520 - val_accuracy: 0.6045
# Epoch 26/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9764 - accuracy: 0.6436 - val_loss: 1.2213 - val_accuracy: 0.5895
# Epoch 27/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9552 - accuracy: 0.6559 - val_loss: 1.5689 - val_accuracy: 0.4990
# Epoch 28/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9516 - accuracy: 0.6519 - val_loss: 1.1565 - val_accuracy: 0.6055
# Epoch 29/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9374 - accuracy: 0.6594 - val_loss: 1.1687 - val_accuracy: 0.6055
# Epoch 30/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9277 - accuracy: 0.6650 - val_loss: 1.3928 - val_accuracy: 0.5460
