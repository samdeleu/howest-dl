# %%
# %matplotlib inline
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import OneHotEncoder
from sklearn import preprocessing

import matplotlib.image as mpimg


from scipy import ndimage
#import Tensorflow namespaces

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation

from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing import image

from tensorflow.keras.callbacks import TensorBoard


import pickle
import time

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# Load training set and test set

training_data = unpickle('./cifar-10/data_batch_1')
test_data = unpickle('./cifar-10/test_batch')

# Create training set and test set

X_train = training_data.get(b'data')
train_labels = training_data.get(b'labels')

X_test = test_data.get(b'data')
test_labels = test_data.get(b'labels')

# Reshape into Tensorflow format (number of images, width, height, color channels)

X_train = X_train.reshape((len(X_train),3,32,32)).transpose(0,2,3,1)
X_test  = X_test.reshape((len(X_test),3,32,32)).transpose(0,2,3,1)

# Normalisatie
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# one-hot encoding of the labels

y_train = to_categorical(train_labels)
y_test = test_labels

# %%
NAME = 'CIFAR-10_CNN_Dropout_10_Percent'.format(int(time.time()))
tensorboard = TensorBoard(log_dir='logs/{}'.format(NAME))

# %%
# Neural network parameters
#-----------------------------------------------
#-----------------------------------------------
batch_size = 64 # 
epochs = 30 # 
dropoutRate = 0.1
#-----------------------------------------------
#-----------------------------------------------
num_classes = 10
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols,3)

# Model
model = Sequential()
#-----------------------------------------------
#-----------------------------------------------
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=input_shape)) 
#-----------------------------------------------
#-----------------------------------------------
model.add(MaxPooling2D(pool_size=(2, 2)))
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(dropoutRate)) # Value between 0 and 1 
#-----------------------------------------------
model.add(BatchNormalization())
#-----------------------------------------------
model.add(Conv2D(32, (3, 3), activation='relu')) 
#-----------------------------------------------
#-----------------------------------------------
model.add(MaxPooling2D(pool_size=(2, 2)))
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(dropoutRate)) # Value between 0 and 1 
#-----------------------------------------------
model.add(BatchNormalization())
#-----------------------------------------------
#-----------------------------------------------
model.add(Flatten()) 
model.add(Dense(50, activation='relu')) 
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(dropoutRate)) # Value between 0 and 1 
#-----------------------------------------------
#-----------------------------------------------
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Trainen van het CNN
history = model.fit(X_train, y_train,batch_size=batch_size, epochs=epochs, validation_split=0.2, verbose=1, callbacks = [tensorboard])
# Out:
# /home/sam/howest/howest-dl/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1743425528.542071  475633 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3574 MB memory:  -> device: 0, name: NVIDIA RTX A3000 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743425532.133397  606477 service.cc:148] XLA service 0x7fbb7401f120 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1743425532.133747  606477 service.cc:156]   StreamExecutor device (0): NVIDIA RTX A3000 Laptop GPU, Compute Capability 8.6
# 2025-03-31 14:52:12.169660: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1743425532.305752  606477 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  14/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1872 - loss: 2.4424
# I0000 00:00:1743425535.386179  606477 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.2853 - loss: 2.0684 - val_accuracy: 0.1800 - val_loss: 2.3735
# Epoch 2/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4777 - loss: 1.5021 - val_accuracy: 0.1920 - val_loss: 2.6018
# Epoch 3/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5299 - loss: 1.3125 - val_accuracy: 0.1835 - val_loss: 2.6433
# Epoch 4/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5782 - loss: 1.1926 - val_accuracy: 0.3255 - val_loss: 1.9552
# Epoch 5/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6188 - loss: 1.0817 - val_accuracy: 0.4445 - val_loss: 1.6221
# Epoch 6/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6397 - loss: 1.0187 - val_accuracy: 0.5640 - val_loss: 1.2314
# Epoch 7/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6715 - loss: 0.9287 - val_accuracy: 0.5295 - val_loss: 1.2651
# Epoch 8/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6885 - loss: 0.8697 - val_accuracy: 0.5660 - val_loss: 1.3164
# Epoch 9/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7193 - loss: 0.7878 - val_accuracy: 0.5615 - val_loss: 1.2679
# Epoch 10/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7287 - loss: 0.7633 - val_accuracy: 0.5660 - val_loss: 1.3388
# Epoch 11/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7446 - loss: 0.7153 - val_accuracy: 0.5285 - val_loss: 1.4243
# Epoch 12/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7542 - loss: 0.6868 - val_accuracy: 0.5975 - val_loss: 1.1978
# Epoch 13/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7701 - loss: 0.6241 - val_accuracy: 0.5445 - val_loss: 1.4473
# Epoch 14/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7878 - loss: 0.6046 - val_accuracy: 0.5965 - val_loss: 1.2601
# Epoch 15/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7937 - loss: 0.5745 - val_accuracy: 0.5645 - val_loss: 1.4324
# Epoch 16/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8050 - loss: 0.5532 - val_accuracy: 0.5965 - val_loss: 1.2667
# Epoch 17/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8134 - loss: 0.5280 - val_accuracy: 0.5680 - val_loss: 1.4646
# Epoch 18/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8300 - loss: 0.4894 - val_accuracy: 0.5715 - val_loss: 1.4322
# Epoch 19/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8341 - loss: 0.4619 - val_accuracy: 0.5780 - val_loss: 1.3732
# Epoch 20/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8390 - loss: 0.4629 - val_accuracy: 0.5755 - val_loss: 1.4832
# Epoch 21/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8549 - loss: 0.4339 - val_accuracy: 0.5920 - val_loss: 1.4808
# Epoch 22/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8459 - loss: 0.4308 - val_accuracy: 0.5880 - val_loss: 1.5532
# Epoch 23/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8577 - loss: 0.3946 - val_accuracy: 0.5905 - val_loss: 1.3687
# Epoch 24/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8678 - loss: 0.3807 - val_accuracy: 0.6090 - val_loss: 1.3986
# Epoch 25/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8735 - loss: 0.3619 - val_accuracy: 0.5895 - val_loss: 1.3868
# Epoch 26/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8621 - loss: 0.3730 - val_accuracy: 0.5950 - val_loss: 1.4852
# Epoch 27/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8781 - loss: 0.3433 - val_accuracy: 0.6080 - val_loss: 1.4482
# Epoch 28/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8800 - loss: 0.3341 - val_accuracy: 0.5945 - val_loss: 1.5635
# Epoch 29/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8786 - loss: 0.3326 - val_accuracy: 0.5095 - val_loss: 2.2255
# Epoch 30/30
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8892 - loss: 0.3163 - val_accuracy: 0.6015 - val_loss: 1.4715

# %%
# Second model


NAME = 'CIFAR-10_CNN_Dropout_30_Percent'.format(int(time.time()))
tensorboard = TensorBoard(log_dir='logs/{}'.format(NAME))

# %%
# Neural network parameters
#-----------------------------------------------
#-----------------------------------------------
batch_size = 64 # 
epochs = 30 # 
dropoutRate = 0.3
#-----------------------------------------------
#-----------------------------------------------
num_classes = 10
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols,3)

# Model
model = Sequential()
#-----------------------------------------------
#-----------------------------------------------
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=input_shape)) 
#-----------------------------------------------
#-----------------------------------------------
model.add(MaxPooling2D(pool_size=(2, 2)))
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(dropoutRate)) # Value between 0 and 1 
#-----------------------------------------------
model.add(BatchNormalization())
#-----------------------------------------------
model.add(Conv2D(32, (3, 3), activation='relu')) 
#-----------------------------------------------
#-----------------------------------------------
model.add(MaxPooling2D(pool_size=(2, 2)))
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(dropoutRate)) # Value between 0 and 1 
#-----------------------------------------------
model.add(BatchNormalization())
#-----------------------------------------------
#-----------------------------------------------
model.add(Flatten()) 
model.add(Dense(50, activation='relu')) 
#-----------------------------------------------
#-----------------------------------------------
model.add(Dropout(dropoutRate)) # Value between 0 and 1 
#-----------------------------------------------
#-----------------------------------------------
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Trainen van het CNN
history = model.fit(X_train, y_train,batch_size=batch_size, epochs=epochs, validation_split=0.2, verbose=1, callbacks = [tensorboard])
# Out:
# Epoch 1/30
# 125/125 [==============================] - 2s 14ms/step - loss: 2.3743 - accuracy: 0.2249 - val_loss: 2.6884 - val_accuracy: 0.1145
# Epoch 2/30
# 125/125 [==============================] - 2s 14ms/step - loss: 1.8452 - accuracy: 0.3425 - val_loss: 3.4860 - val_accuracy: 0.1410
# Epoch 3/30
# 125/125 [==============================] - 2s 14ms/step - loss: 1.6657 - accuracy: 0.3954 - val_loss: 2.8577 - val_accuracy: 0.1355
# Epoch 4/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.5700 - accuracy: 0.4231 - val_loss: 2.5031 - val_accuracy: 0.1865
# Epoch 5/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.4980 - accuracy: 0.4581 - val_loss: 1.9291 - val_accuracy: 0.3345
# Epoch 6/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.4581 - accuracy: 0.4667 - val_loss: 1.8126 - val_accuracy: 0.3625
# Epoch 7/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.4033 - accuracy: 0.4934 - val_loss: 1.4000 - val_accuracy: 0.5110
# Epoch 8/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.3673 - accuracy: 0.5038 - val_loss: 1.6313 - val_accuracy: 0.4170
# Epoch 9/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.3252 - accuracy: 0.5228 - val_loss: 1.3639 - val_accuracy: 0.5200
# Epoch 10/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.2979 - accuracy: 0.5325 - val_loss: 1.4503 - val_accuracy: 0.4795
# Epoch 11/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.2578 - accuracy: 0.5520 - val_loss: 1.2655 - val_accuracy: 0.5400
# Epoch 12/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.2343 - accuracy: 0.5543 - val_loss: 1.2560 - val_accuracy: 0.5520
# Epoch 13/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.2233 - accuracy: 0.5626 - val_loss: 1.2916 - val_accuracy: 0.5350
# Epoch 14/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.1758 - accuracy: 0.5799 - val_loss: 1.3426 - val_accuracy: 0.5560
# Epoch 15/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.1706 - accuracy: 0.5770 - val_loss: 1.3716 - val_accuracy: 0.5215
# Epoch 16/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.1426 - accuracy: 0.5916 - val_loss: 1.5599 - val_accuracy: 0.4795
# Epoch 17/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.1194 - accuracy: 0.5949 - val_loss: 1.2593 - val_accuracy: 0.5630
# Epoch 18/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.0998 - accuracy: 0.6100 - val_loss: 1.1892 - val_accuracy: 0.5805
# Epoch 19/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.0921 - accuracy: 0.6104 - val_loss: 1.2650 - val_accuracy: 0.5710
# Epoch 20/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.0665 - accuracy: 0.6221 - val_loss: 1.2364 - val_accuracy: 0.5695
# Epoch 21/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.0509 - accuracy: 0.6231 - val_loss: 1.2935 - val_accuracy: 0.5545
# Epoch 22/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.0155 - accuracy: 0.6330 - val_loss: 1.2659 - val_accuracy: 0.5570
# Epoch 23/30
# 125/125 [==============================] - 2s 13ms/step - loss: 1.0037 - accuracy: 0.6349 - val_loss: 1.2772 - val_accuracy: 0.5545
# Epoch 24/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9902 - accuracy: 0.6501 - val_loss: 1.2147 - val_accuracy: 0.5785
# Epoch 25/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9848 - accuracy: 0.6389 - val_loss: 1.1520 - val_accuracy: 0.6045
# Epoch 26/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9764 - accuracy: 0.6436 - val_loss: 1.2213 - val_accuracy: 0.5895
# Epoch 27/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9552 - accuracy: 0.6559 - val_loss: 1.5689 - val_accuracy: 0.4990
# Epoch 28/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9516 - accuracy: 0.6519 - val_loss: 1.1565 - val_accuracy: 0.6055
# Epoch 29/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9374 - accuracy: 0.6594 - val_loss: 1.1687 - val_accuracy: 0.6055
# Epoch 30/30
# 125/125 [==============================] - 2s 13ms/step - loss: 0.9277 - accuracy: 0.6650 - val_loss: 1.3928 - val_accuracy: 0.5460
